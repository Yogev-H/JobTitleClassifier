# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import glob
import re
import string
from bs4 import BeautifulSoup

# sklearn
from sklearn.feature_extraction.text import CountVectorizer,TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, precision_score, recall_score, f1_score

# nltk
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords 

# visualization 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\yhadad\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\yhadad\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df = pd.read_csv('datasets\processed_data.csv')

# %%
df.head()
# Out:
#                                          Description                 JobTitle
# 0  ['avis', 'budget', 'group', 'actionpacked', 'h...    Automotive Technician
# 1  ['position', 'licensed', 'practical', 'nurse',...  Nurse Practitioner (NP)
# 2  ['service', 'technician', 'every', 'employee',...    Automotive Technician
# 3  ['avis', 'budget', 'group', 'actionpacked', 'h...    Automotive Technician
# 4  ['job', 'purpose', 'nurse', 'practitioner', 'p...  Nurse Practitioner (NP)

# %%
X_train, X_test, y_train, y_test = train_test_split(df['Description'], df['JobTitle'], test_size=0.3,
                                                    random_state=42, stratify=df['JobTitle'])

# %% [markdown]
# ## RandomForestClassifier

# %%
rf = RandomForestClassifier()

pipline = Pipeline(steps=[
    ('bow', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
    ('model', rf)
])

# %%
from sklearn.model_selection import RandomizedSearchCV

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 1000, num = 5)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(2, 15, num = 5)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]

# %% [markdown]
# On each iteration, the algorithm will choose a difference combination of the features. Altogether, there are 5 * 2 * 6 * 3 * 3 * 2 = 1080 settings! However, the benefit of a random search is that we are not trying every combination, but selecting at random to sample a wide range of values.

# %%
# hyperparameter tuning
def grid_search():
    param_grid = {
        'model__n_estimators': n_estimators,
        'model__max_features': max_features,
        'model__max_depth': max_depth,
        'model__min_samples_split': min_samples_split,
        'model__min_samples_leaf': min_samples_leaf,
        'model__bootstrap': bootstrap
    }

    search = RandomizedSearchCV(pipline, param_grid, cv=5, n_jobs=-1)
    search.fit(X_train,y_train)

    print("Best parameter (CV score=%0.3f):" % search.best_score_)
    print(search.best_params_)

# %%
import time

start = time.time()

grid_search()

end = time.time()
print('execution time in minutes: ', (end - start)/60)
# Out:
# Best parameter (CV score=0.780):
# {'model__n_estimators': 800, 'model__min_samples_split': 10, 'model__min_samples_leaf': 2, 'model__max_features': 'auto', 'model__max_depth': None, 'model__bootstrap': True}
# execution time in minutes:  19.17095280488332

# %%
# adding best hyperparameter

rf = RandomForestClassifier(min_samples_split = 10, max_depth=None, n_estimators = 800, min_samples_leaf = 2,
                            max_features = 'auto',bootstrap = True)

pipline = Pipeline(steps=[
    ('bow', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
    ('model', rf)
])

# %%
pipline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('bow', CountVectorizer()), ('tfidf', TfidfTransformer()),
#                 ('model',
#                  RandomForestClassifier(min_samples_leaf=2,
#                                         min_samples_split=10,
#                                         n_estimators=800))])

# %%
predictions = pipline.predict(X_test)

# %%
print(classification_report(y_test, predictions))
# Out:
#                                                 precision    recall  f1-score   support
#
#                                     Accountant       0.50      0.22      0.31         9
#      Accounts Payable or Receivable Specialist       0.60      0.88      0.71        17
#                            Addiction Counselor       0.71      0.62      0.67         8
#                       Administrative Assistant       0.51      0.82      0.63        22
#                             Analytical Chemist       1.00      0.25      0.40         4
#                               Anesthesiologist       0.90      0.56      0.69        16
#                                   Art Director       1.00      0.60      0.75         5
#                                      Assembler       0.62      0.83      0.71        84
#                   Assistant Restaurant Manager       0.65      0.65      0.65        31
#                        Assistant Store Manager       0.57      0.81      0.67        16
#                           Autism (ASD) Teacher       0.00      0.00      0.00         4
#                       Automotive Body Repairer       0.67      0.67      0.67         3
#                            Automotive Detailer       1.00      0.85      0.92        13
#                           Automotive Estimator       1.00      0.86      0.92         7
#                     Automotive Service Advisor       1.00      1.00      1.00         4
#                          Automotive Technician       0.88      0.54      0.67        13
#                             Operations Manager       1.00      0.40      0.57         5
#                          Operations Specialist       0.60      0.43      0.50         7
#                          Operations Supervisor       0.80      0.80      0.80         5
#                                    Order Clerk       0.00      0.00      0.00         6
#                                   Orthodontist       1.00      1.00      1.00         6
#              Over the Road Driver (OTR Driver)       1.00      0.33      0.50         3
#                                     PACU Nurse       0.00      0.00      0.00         4
#                                       Packager       0.97      0.97      0.97       518
#                        Passenger Service Agent       1.00      1.00      1.00         5
#                  Patient Care Technician (PCT)       0.83      0.83      0.83         6
#                             Payroll Specialist       1.00      0.40      0.57         5
#                                Pediatric Nurse       0.00      0.00      0.00         8
#               Pediatric Occupational Therapist       0.85      0.80      0.82        44
#          Pediatric Speech Language Pathologist       0.75      0.87      0.81       287
#                                   Pediatrician       0.00      0.00      0.00         4
#                       Pharmaceutical Scientist       1.00      0.25      0.40         4
#                            Pharmacy Technician       1.00      0.94      0.97        17
#                        Physical Therapist (PT)       0.91      0.77      0.83        64
#             Physical Therapist Assistant (PTA)       0.86      0.83      0.84        29
#                                      Physician       0.57      0.25      0.35        16
#                            Physician Assistant       0.00      0.00      0.00         4
#                    Pick Up and Delivery Driver       0.79      0.88      0.84       188
#                                    Pizza Maker       1.00      0.67      0.80         6
#                                        Plumber       0.60      0.75      0.67         4
#                                      Prep Cook       0.50      0.73      0.59        26
#                         Press Machine Operator       0.00      0.00      0.00         6
#                       Pressure Washer Operator       0.00      0.00      0.00         7
#                         Primary Care Physician       0.71      0.80      0.75        15
#                             Process Technician       1.00      0.50      0.67         4
#                               Product Designer       1.00      0.25      0.40         4
#                                Product Manager       1.00      0.40      0.57         5
#                                  Product Owner       0.25      0.20      0.22         5
#                         Production Line Worker       0.00      0.00      0.00        12
#                             Production Planner       0.00      0.00      0.00         7
#                          Production Supervisor       0.00      0.00      0.00         6
#                          Production Technician       0.86      0.30      0.44        20
#                              Production Worker       0.51      0.71      0.59       104
#                                Program Manager       1.00      0.43      0.60         7
#                                     Programmer       0.00      0.00      0.00         4
#                                Project Manager       0.33      0.30      0.32        10
#                               Proposal Manager       0.88      0.88      0.88         8
#                                Proposal Writer       1.00      0.80      0.89         5
#                              Psychiatric Nurse       0.57      0.31      0.40        13
#                                   Psychiatrist       0.65      0.92      0.76        38
#                                   Psychologist       0.57      0.50      0.53         8
#                               Purchasing Agent       0.67      0.50      0.57         4
#    Quality Control / Quality Assurance Analyst       1.00      0.11      0.20         9
#   Quality Control / Quality Assurance Engineer       0.47      0.73      0.57        11
#    Quality Control / Quality Assurance Manager       0.00      0.00      0.00         5
#  Quality Control / Quality Assurance Scientist       1.00      0.75      0.86         4
# Quality Control / Quality Assurance Specialist       0.38      0.40      0.39        15
# Quality Control / Quality Assurance Technician       0.50      0.21      0.30        14
#                             Quality Controller       0.80      0.83      0.82        24
#                                    Radiologist       0.50      0.50      0.50         6
#                                     Ramp Agent       1.00      0.86      0.92         7
#                                   Receptionist       1.00      0.42      0.59        12
#                                      Recruiter       0.69      0.61      0.65        18
#              Registered Dental Assistant (RDA)       0.90      0.90      0.90        87
#                          Registered Nurse (RN)       0.71      0.96      0.81       210
#               Regulatory Compliance Specialist       1.00      0.80      0.89         5
#                        Rehabilitation Director       1.00      0.60      0.75         5
#                             Research Associate       0.40      0.82      0.54        22
#                          Respiratory Therapist       1.00      0.82      0.90        28
#                             Restaurant Manager       0.71      0.43      0.53        28
#                          Restaurant Supervisor       0.40      1.00      0.57         4
#                         Restoration Technician       1.00      1.00      1.00         4
#                           Retail Sales Manager       1.00      0.83      0.91         6
#                    Retail Sales Representative       1.00      0.98      0.99       243
#                            Retail Stock Person       0.50      0.20      0.29         5
#                                         Roofer       1.00      1.00      1.00         4
#                                   Route Driver       0.65      0.65      0.65        17
#                        Sales Account Executive       0.60      0.60      0.60         5
#                          Sales Account Manager       1.00      0.67      0.80         6
#                                  Sales Manager       0.96      0.88      0.92        25
#                           Sales Representative       0.87      0.88      0.88       120
#                                  Salon Manager       1.00      1.00      1.00        12
#                              Sanitation Worker       0.60      0.48      0.53        25
#                                   School Nurse       0.99      0.89      0.94        75
#                            School Psychologist       0.88      0.98      0.93       185
#                                 Security Guard       1.00      0.83      0.91         6
#                              Senior Accountant       0.43      0.88      0.58        17
#                       Senior Financial Analyst       0.50      0.25      0.33         4
#                               Senior Scientist       0.50      0.58      0.54        12
#                       Senior Software Engineer       0.00      0.00      0.00         5
#                             Shipper / Receiver       0.50      0.40      0.44         5
#                     Shipping / Receiving Clerk       1.00      0.09      0.17        11
#                      Sign Language Interpreter       1.00      0.60      0.75         5
#                                  Social Worker       0.97      0.66      0.78        44
#                              Software Engineer       0.38      0.56      0.45         9
#                                Solar Installer       0.78      1.00      0.88        32
#            Special Education Preschool Teacher       0.00      0.00      0.00         7
#                      Special Education Teacher       0.84      0.99      0.91       161
#              Speech Language Pathologist (SLP)       0.72      0.75      0.73       127
#          Speech Language Pathologist Assistant       1.00      0.36      0.53        22
#                               Staff Accountant       0.60      0.27      0.37        11
#                                    Staff Nurse       1.00      0.33      0.50         6
#                                Staff Scientist       0.35      0.44      0.39        16
#                            Staffing Specialist       1.00      0.99      0.99       100
#                                  Store Manager       0.75      0.60      0.67         5
#                                  Store Shopper       1.00      0.43      0.61        46
#                                   Store Worker       0.76      0.88      0.82       171
#                            Surgical Technician       1.00      0.57      0.73         7
#                           System Administrator       0.89      0.57      0.70        14
#                              Teacher Assistant       1.00      0.40      0.57        10
#               Technical Support Representative       0.00      0.00      0.00         3
#                               Technical Writer       0.50      0.25      0.33         4
#                                   Travel Nurse       0.80      0.98      0.88       133
#                                   Truck Driver       0.96      0.91      0.93       140
#                                    UX Designer       0.83      0.71      0.77         7
#                                 Utility Worker       0.00      0.00      0.00         3
#                 Visually Impaired (VI) Teacher       1.00      0.38      0.55         8
#                              Waiter (Waitress)       0.89      0.93      0.91        27
#                                Warehouse Clerk       0.22      0.15      0.18        13
#                               Warehouse Worker       0.75      0.94      0.84       475
#                                Waste Collector       0.65      0.77      0.71        44
#                                   Waste Sorter       0.17      0.10      0.12        10
#                                   Web Designer       0.75      0.67      0.71         9
#                                  Web Developer       0.27      0.57      0.36         7
#                                         Welder       0.85      0.81      0.83        21
#                          Windows Administrator       0.80      0.67      0.73         6
#                              Writer and Author       0.00      0.00      0.00         4
#                                 Yard Operative       0.71      0.71      0.71        14
#
#                                       accuracy                           0.78      7938
#                                      macro avg       0.69      0.55      0.58      7938
#                                   weighted avg       0.78      0.78      0.77      7938
# C:\Users\yhadad\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
