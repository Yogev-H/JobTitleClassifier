# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\yhadad\\Desktop\\DS\\NLP JT Classifier'

# %%
sns.set_style('white')
pd.set_option('max_colwidth',150)

# %%
df = pd.read_parquet('job_title_dataset.parquet')

# %%
df.shape
# Out:
# (1100, 4)

# %%
df.head(10)
# Out:
#        JobId  JobTitleId                            JobTitle  \
# 0   36126335      400878  Physical Therapist Assistant (PTA)
# 1   39345757      400720          Automotive Service Manager
# 2   84331465      407973          Wastewater Project Manager
# 3   88112060      402654                      Neonatal Nurse
# 4   88112450      402654                      Neonatal Nurse
# 5   88112460      402654                      Neonatal Nurse
# 6   88112463      402654                      Neonatal Nurse
# 7   88114236      402654                      Neonatal Nurse
# 8   88114375      402654                      Neonatal Nurse
# 9  105364828      402654                      Neonatal Nurse
#
#                                                                                                                                              Description
# 0  <p>Looking for part-time PT&nbsp;for a quick growing and dynamic outpatient physical therapy clinic. Mentorship available and encouraged!&nbsp; Ou...
# 1  At David Maus Toyota, we strive to make every customer a customer for life.<br/> Happy employees make happy customers, and we reward individuals w...
# 2  <p>Position Summary:</p>\n<p>Project Management personnel are responsible for the overall safety, direction, completion, and financial outcome of ...
# 3  <p>Envision Physician Services is seeking a Neonatal Nurse Practitioner to join our busy practice covering 7 Medical City facilities in the DFW ar...
# 4  <p>Envision Physician Services is seeking a Neonatal Nurse Practitioner to join our busy practice covering 7 Medical City facilities in the DFW ar...
# 5  <p>Envision Physician Services is seeking a Neonatal Nurse Practitioner to join our busy practice covering 7 Medical City facilities in the DFW ar...
# 6  <p>$20,000 start date bonus!</p><p>Envision Physician Services is seeking a certified and experienced Neonatal Nurse Practitioner or Physician Ass...
# 7  <p>Envision Physician Services is seeking a dynamic, board certified, Neonatal Nurse Practitioner Embassador to join our Women&rsquo;s and Childre...
# 8  <p>Envision Physician Services is seeking a Neonatal Nurse Practitioner to join our busy practice covering 7 Medical City facilities in the DFW ar...
# 9  <p>Night Shift Neonatal Nurse Practitioner Opportunity in Level III NICU in Panama City! Envision Physician Services is seeking an experienced NNP...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   JobId        1100 non-null   object
#  1   JobTitleId   1100 non-null   int32
#  2   JobTitle     1100 non-null   object
#  3   Description  1099 non-null   object
# dtypes: int32(1), object(3)
# memory usage: 30.2+ KB

# %%
# remove nulls

df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1099 entries, 0 to 1099
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   JobId        1099 non-null   object
#  1   JobTitleId   1099 non-null   int32
#  2   JobTitle     1099 non-null   object
#  3   Description  1099 non-null   object
# dtypes: int32(1), object(3)
# memory usage: 38.6+ KB

# %%
df[(df.Description == 'None') | (df.Description == '')]
# Out:
# Empty DataFrame
# Columns: [JobId, JobTitleId, JobTitle, Description]
# Index: []

# %%
# count unique values for each column

def count_unique(data):
    for col in data.columns:
        print (f" In the '{col}' column there are: {data[col].nunique()} unique values")

# %%
count_unique(df)
# Out:
#  In the 'JobId' column there are: 1099 unique values
#  In the 'JobTitleId' column there are: 51 unique values
#  In the 'JobTitle' column there are: 51 unique values
#  In the 'Description' column there are: 1099 unique values

# %%
# duplicates 

df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [JobId, JobTitleId, JobTitle, Description]
# Index: []

# %% [markdown]
# ## Cleaning The Data
#
# **Common data cleaning steps on all text:**
#
# * Make text all lower case
# * Remove punctuation
# * Remove THML tags
# * Remove numerical values
# * Remove common non-sensical text (/n)
# * Tokenize text
# * Remove stop words
#
#
# **More data cleaning steps after tokenization:**
#
# * Stemming / lemmatization
# * Create bi-grams or tri-grams
# * Deal with typos

# %%
print('raw dataset: {}'.format(len(df.Description.iloc[0])))
df.Description.iloc[0]
# Out:
# raw dataset: 2122
# "<p>Looking for part-time PT&nbsp;for a quick growing and dynamic outpatient physical therapy clinic. Mentorship available and encouraged!&nbsp; Our clinic focuses on manual therapy and exercise in a well equipped clinic with the latest equipment and modalities. We take an active approach to rehabilitation and always take the time to care. Our clinic offers personalized physical therapy in a warm and caring environment. Every day is a positive day at Andrew PT! Very manageable daily case load of 8-10 patients per day so you can spend the quality time with patients that makes work and life enjoyable!&nbsp; On a separate note, we&nbsp;also have all the necessary equipment and private treatment room for a women's health&nbsp;program if you have those clinical skills or interest.</p> <p>Our clinic is cutting edge and is even solar powered. Large vaulted ceiling workout area and 9 personalized treatment rooms with the clinic spanning 4,000 square feet total. Our clinic is located in McMinnville, OR which is perfectly situated for the recreational enthusiast. One can be at the beach, in the mountains hiking or cycling within minutes. Mentorship is available and encouraged as we believe personal growth is one of the key ingredients to keep us happy as clinicians. Personal growth through continued learning and education helps keep us motivated and also helps us to better serve our patients. New graduates are welcome as well as the therapist with experience.&nbsp; For more information please contact via e-mail&nbsp;(john.andrewpt@gmail.com)&nbsp;or fax your resume to to (503) 435-1930. You may also visit our website at www.AndrewPT.com. 72K+ salary per year to start for DPT depending on experience. Benefits for full-time work: Competitive salary, 401K w/ company matching &amp; Profit Sharing, Employee full medical and dental coverage,&nbsp;4 wks paid vacation (including 6 paid Holidays over 5 weeks paid time off per year), yearly bonus based on performance/profits, 6 major Holidays paid per year, OR PT yearly licensing fee paid, $1,200 yearly continuing education fund, more benefits as well.</p>"

# %%
# pip install nltk

# %%
# Apply a first round of text cleaning techniques

import re
import string
from nltk.corpus import stopwords 
from bs4 import BeautifulSoup

def text_process(text):
    """
    1. make text lowercase
    2. remove html tags
    3. remove punctuation 
    4. remove words containing numbers
    5. return set of clean text words
    """
    
    text = text.lower()
    text = re.sub('<.*?>', '', text)
    text = BeautifulSoup(text).get_text()
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = [word for word in text.split() if word.lower() not in stopwords.words('english')] 
    text = list(set(text))
    
    return text

round1= lambda x: text_process(x)

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\yhadad\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\yhadad\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# from nltk.corpus import stopwords
stopwords.words('english')[0:10] # Show some stop words
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]

# %%
print('raw dataset: {}'.format(len(text_process(df['Description'][0]))))
text_process(df['Description'][0])
# Out:
# raw dataset: 156
# ['manageable',
#  'full',
#  'available',
#  'cutting',
#  'coverage',
#  'company',
#  'clinic',
#  'based',
#  'growing',
#  'powered',
#  'dental',
#  'rooms',
#  'physical',
#  'parttime',
#  'sharing',
#  'serve',
#  'large',
#  'quality',
#  'fee',
#  'work',
#  'perfectly',
#  'focuses',
#  'fulltime',
#  'per',
#  'w',
#  'solar',
#  'resume',
#  'spanning',
#  'fund',
#  'fax',
#  'located',
#  'personalized',
#  'patients',
#  'separate',
#  'always',
#  'motivated',
#  'well',
#  'exercise',
#  'key',
#  'therapist',
#  'bonus',
#  'website',
#  'pt',
#  'total',
#  'take',
#  'us',
#  'weeks',
#  'care',
#  'vaulted',
#  'recreational',
#  'please',
#  'depending',
#  'licensing',
#  'cycling',
#  'dynamic',
#  'workout',
#  'information',
#  'situated',
#  'also',
#  'personal',
#  'year',
#  'start',
#  'minutes',
#  'paid',
#  'encouraged',
#  'offers',
#  'performanceprofits',
#  'interest',
#  'keep',
#  'benefits',
#  'wwwandrewptcom',
#  'enthusiast',
#  'beach',
#  'vacation',
#  'manual',
#  'edge',
#  'treatment',
#  'continued',
#  'warm',
#  'johnandrewptgmailcom',
#  'happy',
#  'may',
#  'latest',
#  'spend',
#  'program',
#  'looking',
#  'square',
#  'competitive',
#  'feet',
#  'private',
#  'every',
#  'time',
#  'room',
#  'positive',
#  'contact',
#  'employee',
#  'education',
#  'wks',
#  'salary',
#  'environment',
#  'email',
#  'area',
#  'welcome',
#  'including',
#  'experience',
#  'health',
#  'ingredients',
#  'hiking',
#  'daily',
#  'quick',
#  'ceiling',
#  'modalities',
#  'major',
#  'clinicians',
#  'dpt',
#  'yearly',
#  'equipped',
#  'approach',
#  'better',
#  'skills',
#  'graduates',
#  'outpatient',
#  'necessary',
#  'holidays',
#  'case',
#  'medical',
#  'continuing',
#  'load',
#  'womens',
#  'enjoyable',
#  'note',
#  'therapy',
#  'mcminnville',
#  'one',
#  'helps',
#  'clinical',
#  'andrew',
#  'active',
#  'rehabilitation',
#  'via',
#  'equipment',
#  'believe',
#  'makes',
#  'mountains',
#  'growth',
#  'life',
#  'learning',
#  'profit',
#  'mentorship',
#  'day',
#  'matching',
#  'caring',
#  'within',
#  'even',
#  'new',
#  'visit']

# %%
# Let's take a look at the updated text
df['Desc'] = pd.DataFrame(df.Description.apply(round1))
df.head()
# Out:
#       JobId  JobTitleId                            JobTitle  \
# 0  36126335      400878  Physical Therapist Assistant (PTA)
# 1  39345757      400720          Automotive Service Manager
# 2  84331465      407973          Wastewater Project Manager
# 3  88112060      402654                      Neonatal Nurse
# 4  88112450      402654                      Neonatal Nurse
#
#                                                                                                                                              Description  \
# 0  <p>Looking for part-time PT&nbsp;for a quick growing and dynamic outpatient physical therapy clinic. Mentorship available and encouraged!&nbsp; Ou...
# 1  At David Maus Toyota, we strive to make every customer a customer for life.<br/> Happy employees make happy customers, and we reward individuals w...
# 2  <p>Position Summary:</p>\n<p>Project Management personnel are responsible for the overall safety, direction, completion, and financial outcome of ...
# 3  <p>Envision Physician Services is seeking a Neonatal Nurse Practitioner to join our busy practice covering 7 Medical City facilities in the DFW ar...
# 4  <p>Envision Physician Services is seeking a Neonatal Nurse Practitioner to join our busy practice covering 7 Medical City facilities in the DFW ar...
#
#                                                                                                                                                     Desc  \
# 0  [manageable, full, available, cutting, coverage, company, clinic, based, growing, powered, dental, rooms, physical, parttime, sharing, serve, larg...
# 1  [successour, receive, stay, additional, offholidays, phone, years, appearance, dental, background, manage, training, mishandled, ownership, work, ...
# 2  [teamwork, forecast, complies, regard, supervision, excellent, building, jobs, water, overall, employer, software, company, required, members, gen...
# 3  [units, providers, coverage, eight, based, worth, malpractice, years, ambulatory, dallasfort, strategic, join, rooms, implementing, areas, quality...
# 4  [units, providers, coverage, based, worth, malpractice, years, ambulatory, dallasfort, strategic, join, rooms, implementing, areas, statedesignate...
#
#    DescLength  DescriptionLength
# 0         156               2122
# 1         114               1585
# 2         211               3306
# 3         132               1850
# 4         142               2002

# %%
# before cleaning

df.Description[1080]
# Out:
# '<div dir="ltr"> </div><br><br><div dir="ltr"><br><div dir="ltr"><br><div><br><div><br><div><br><p><span style="font-size:12pt"><span style="background:white"><span style="vertical-align:baseline"><span style="font-family:Calibri,sans-serif"><b><span style="border:none windowtext 1.0pt; font-size:11.0pt; padding:0in"><span style="font-family:&amp;quot;Times New Roman&amp;quot;,serif"><span style="color:black">Software Engineer AdTech</span></span></span></b></span></span></span></span></p><br><br><p> </p><br'

# %%
# after cleaning

df.Desc[1080]
# Out:
# {'adtech', 'engineer', 'software'}

# %%
df['DescLength'] = df.Desc.apply(len)
df['DescriptionLength'] = df.Description.apply(len)

# %%
fig, axes = plt.subplots(1,2, figsize=(20,6))

# both subplots title
fig.suptitle('Description Length')

# plot1 object
sns.histplot(df['DescriptionLength'],ax=axes[0])
axes[0].set_title('Description Length histogram (before cleaning)')

# plot2 object
sns.histplot(df['DescLength'],ax=axes[1])
axes[1].set_title('Description Length histogram (after cleaning)')

# show plot
plt.show()

# %%
df[df.DescLength < 50].sort_values(by='DescLength').head()
# Out:
#           JobId  JobTitleId                            JobTitle  \
# 1080  496707274          21                   Software Engineer
# 984   485094592          21                   Software Engineer
# 1081  496707802          21                   Software Engineer
# 1028  490692864          21                   Software Engineer
# 1013  489720793      400878  Physical Therapist Assistant (PTA)
#
#                                                                                                                                                 Description  \
# 1080  <div dir="ltr"> </div><br><br><div dir="ltr"><br><div dir="ltr"><br><div><br><div><br><div><br><p><span style="font-size:12pt"><span style="backgr...
# 984   <html><body><p><span style="font-family: arial, helvetica, sans-serif; font-size: 11pt;"><b><span style="text-decoration: none;">TITLE</span></b><...
# 1081  <p><span style="font-size:11pt"><span style="font-family:Calibri,sans-serif"><b><span style="font-family:&amp;quot;Cambria&amp;quot;,&amp;quot;ser...
# 1028  <p class="MsoNormal"><strong style="mso-bidi-font-weight: normal;"><span style="font-size: 10.0pt; line-height: 115%; font-family: 'Helv',sans-ser...
# 1013  <p><i style="color: black; font-family: Cambria, serif; font-size: 10pt;">We’re looking for an exceptional </i><b style="color: black; font-family...
#
#                                                                                     Desc  \
# 1080                                                        [adtech, software, engineer]
# 984                                        [remote, engineer, location, title, software]
# 1081                      [employment, engineer, nnjob, contract, title, type, software]
# 1028               [solutions, job, engineer, practice, requisition, software, advanced]
# 1013  [exceptional, school, looking, we’re, fulltime, physical, assistant, p, therapist]
#
#       DescLength  DescriptionLength
# 1080           3                512
# 984            5                512
# 1081           7                512
# 1028           7                512
# 1013           9                512

# %%
df.loc[999,'Description']
# Out:
# '<div><div data-bind="css: $component.getBlockCellCss($data, 0)" class="block__cell block__field--wide-rich-text" style="font-family: &quot;Open Sans&quot;, &quot;Segoe UI&quot;, Frutiger, &quot;Frutiger Linotype&quot;, &quot;Dejavu Sans&quot;, &quot;Helvetica Neue&quot;, Arial, sans-serif; font-size: 13.02px; padding: 0px 25px 0px 0px; margin: 10px 0px 0px; width: 961.667px; box-sizing: border-box;"><div data-bind="attr: {id: $data.name + \'-container\',\n        class:(\n        $data.displayType === \'InputTex'

# %%
df.loc[275,'Description']
# Out:
# '<p style="margin: 0px;">x</p><br><p style="margin: 0px;">x</p><br><p style="margin: 0px;">x</p>'

# %%
df[df.DescriptionLength <100].head()
# Out:
# Empty DataFrame
# Columns: [JobId, JobTitleId, JobTitle, Description, Desc, DescLength, DescriptionLength]
# Index: []

# %%
# removing rows with no valid text in the Description 

df.drop(df[(df.DescriptionLength < 100)|(df.DescLength < 3)].index, inplace=True)

# %%
# looks like we were able to clean a lot of unnecessary text

df.describe()
# Out:
#           JobTitleId   DescLength  DescriptionLength
# count    1097.000000  1097.000000        1097.000000
# mean   260940.872379   179.481313        3110.663628
# std    190654.543678   103.711673        2184.767587
# min        21.000000     3.000000         281.000000
# 25%        21.000000    86.000000        1484.000000
# 50%    400832.000000   188.000000        3034.000000
# 75%    402654.000000   251.000000        4277.000000
# max    410520.000000   616.000000       21330.000000

# %% [markdown]
# ## lemmatization

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

test = df.loc[0,'Desc']

lemmatized = [lemmatizer.lemmatize(w) for w in test]

print(len((set(lemmatized))))

lemmatized
# Out:
# 155
# ['manageable',
#  'full',
#  'available',
#  'cutting',
#  'coverage',
#  'company',
#  'clinic',
#  'based',
#  'growing',
#  'powered',
#  'dental',
#  'room',
#  'physical',
#  'parttime',
#  'sharing',
#  'serve',
#  'large',
#  'quality',
#  'fee',
#  'work',
#  'perfectly',
#  'focus',
#  'fulltime',
#  'per',
#  'w',
#  'solar',
#  'resume',
#  'spanning',
#  'fund',
#  'fax',
#  'located',
#  'personalized',
#  'patient',
#  'separate',
#  'always',
#  'motivated',
#  'well',
#  'exercise',
#  'key',
#  'therapist',
#  'bonus',
#  'website',
#  'pt',
#  'total',
#  'take',
#  'u',
#  'week',
#  'care',
#  'vaulted',
#  'recreational',
#  'please',
#  'depending',
#  'licensing',
#  'cycling',
#  'dynamic',
#  'workout',
#  'information',
#  'situated',
#  'also',
#  'personal',
#  'year',
#  'start',
#  'minute',
#  'paid',
#  'encouraged',
#  'offer',
#  'performanceprofits',
#  'interest',
#  'keep',
#  'benefit',
#  'wwwandrewptcom',
#  'enthusiast',
#  'beach',
#  'vacation',
#  'manual',
#  'edge',
#  'treatment',
#  'continued',
#  'warm',
#  'johnandrewptgmailcom',
#  'happy',
#  'may',
#  'latest',
#  'spend',
#  'program',
#  'looking',
#  'square',
#  'competitive',
#  'foot',
#  'private',
#  'every',
#  'time',
#  'room',
#  'positive',
#  'contact',
#  'employee',
#  'education',
#  'wks',
#  'salary',
#  'environment',
#  'email',
#  'area',
#  'welcome',
#  'including',
#  'experience',
#  'health',
#  'ingredient',
#  'hiking',
#  'daily',
#  'quick',
#  'ceiling',
#  'modality',
#  'major',
#  'clinician',
#  'dpt',
#  'yearly',
#  'equipped',
#  'approach',
#  'better',
#  'skill',
#  'graduate',
#  'outpatient',
#  'necessary',
#  'holiday',
#  'case',
#  'medical',
#  'continuing',
#  'load',
#  'woman',
#  'enjoyable',
#  'note',
#  'therapy',
#  'mcminnville',
#  'one',
#  'help',
#  'clinical',
#  'andrew',
#  'active',
#  'rehabilitation',
#  'via',
#  'equipment',
#  'believe',
#  'make',
#  'mountain',
#  'growth',
#  'life',
#  'learning',
#  'profit',
#  'mentorship',
#  'day',
#  'matching',
#  'caring',
#  'within',
#  'even',
#  'new',
#  'visit']

# %%
words = ['run', 'running', 'ran','go', 'going', 'goes', 'went']

# %%
[lemmatizer.lemmatize(w) for w in words]
# Out:
# ['run', 'running', 'ran', 'go', 'going', 'go', 'went']

# %% [markdown]
# ## Stemming

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

stemming = PorterStemmer()
stemming = [stemming.stem(w) for w in test]
print(len(set(stemming)))
stemming
# Out:
# 150
# ['manag',
#  'full',
#  'avail',
#  'cut',
#  'coverag',
#  'compani',
#  'clinic',
#  'base',
#  'grow',
#  'power',
#  'dental',
#  'room',
#  'physic',
#  'parttim',
#  'share',
#  'serv',
#  'larg',
#  'qualiti',
#  'fee',
#  'work',
#  'perfectli',
#  'focus',
#  'fulltim',
#  'per',
#  'w',
#  'solar',
#  'resum',
#  'span',
#  'fund',
#  'fax',
#  'locat',
#  'person',
#  'patient',
#  'separ',
#  'alway',
#  'motiv',
#  'well',
#  'exercis',
#  'key',
#  'therapist',
#  'bonu',
#  'websit',
#  'pt',
#  'total',
#  'take',
#  'us',
#  'week',
#  'care',
#  'vault',
#  'recreat',
#  'pleas',
#  'depend',
#  'licens',
#  'cycl',
#  'dynam',
#  'workout',
#  'inform',
#  'situat',
#  'also',
#  'person',
#  'year',
#  'start',
#  'minut',
#  'paid',
#  'encourag',
#  'offer',
#  'performanceprofit',
#  'interest',
#  'keep',
#  'benefit',
#  'wwwandrewptcom',
#  'enthusiast',
#  'beach',
#  'vacat',
#  'manual',
#  'edg',
#  'treatment',
#  'continu',
#  'warm',
#  'johnandrewptgmailcom',
#  'happi',
#  'may',
#  'latest',
#  'spend',
#  'program',
#  'look',
#  'squar',
#  'competit',
#  'feet',
#  'privat',
#  'everi',
#  'time',
#  'room',
#  'posit',
#  'contact',
#  'employe',
#  'educ',
#  'wk',
#  'salari',
#  'environ',
#  'email',
#  'area',
#  'welcom',
#  'includ',
#  'experi',
#  'health',
#  'ingredi',
#  'hike',
#  'daili',
#  'quick',
#  'ceil',
#  'modal',
#  'major',
#  'clinician',
#  'dpt',
#  'yearli',
#  'equip',
#  'approach',
#  'better',
#  'skill',
#  'graduat',
#  'outpati',
#  'necessari',
#  'holiday',
#  'case',
#  'medic',
#  'continu',
#  'load',
#  'women',
#  'enjoy',
#  'note',
#  'therapi',
#  'mcminnvil',
#  'one',
#  'help',
#  'clinic',
#  'andrew',
#  'activ',
#  'rehabilit',
#  'via',
#  'equip',
#  'believ',
#  'make',
#  'mountain',
#  'growth',
#  'life',
#  'learn',
#  'profit',
#  'mentorship',
#  'day',
#  'match',
#  'care',
#  'within',
#  'even',
#  'new',
#  'visit']

# %%
stem = PorterStemmer()
[stem.stem(w) for w in words]
# Out:
# ['run', 'run', 'ran', 'go', 'go', 'goe', 'went']

# %%
comparing_df = pd.DataFrame(test,columns=['original'])
comparing_df['stemming'] = stemming
comparing_df['lemmatization'] = lemmatized
comparing_df.drop_duplicates().head(20)
# Out:
#       original stemming lemmatization
# 0   manageable    manag    manageable
# 1         full     full          full
# 2    available    avail     available
# 3      cutting      cut       cutting
# 4     coverage  coverag      coverage
# 5      company  compani       company
# 6       clinic   clinic        clinic
# 7        based     base         based
# 8      growing     grow       growing
# 9      powered    power       powered
# 10      dental   dental        dental
# 11       rooms     room          room
# 12    physical   physic      physical
# 13    parttime  parttim      parttime
# 14     sharing    share       sharing
# 15       serve     serv         serve
# 16       large     larg         large
# 17     quality  qualiti       quality
# 18         fee      fee           fee
# 19        work     work          work

# %% [markdown]
# ## Create bi-grams or tri-grams

# %% [markdown]
# ## Deal with typos

# %% [markdown]
# ## CountVectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
bow_transformer = CountVectorizer(analyzer=text_process).fit(df['Description'])

# Print total number of vocab words
print(len(bow_transformer.vocabulary_))
# Out:
# 15995

# %%
bow_transformer.vocabulary_
# Out:
# {'manageable': 8285,
#  'full': 5789,
#  'available': 1214,
#  'cutting': 3329,
#  'coverage': 3121,
#  'company': 2614,
#  'clinic': 2353,
#  'based': 1322,
#  'growing': 6158,
#  'powered': 10709,
#  'dental': 3629,
#  'rooms': 12340,
#  'physical': 10387,
#  'parttime': 10122,
#  'sharing': 12871,
#  'serve': 12767,
#  'large': 7758,
#  'quality': 11427,
#  'fee': 5355,
#  'work': 15693,
#  'perfectly': 10262,
#  'focuses': 5568,
#  'fulltime': 5797,
#  'per': 10251,
#  'w': 15380,
#  'solar': 13195,
#  'resume': 12152,
#  'spanning': 13289,
#  'fund': 5823,
#  'fax': 5314,
#  'located': 8114,
#  'personalized': 10312,
#  'patients': 10160,
#  'separate': 12751,
#  'always': 557,
#  'motivated': 8952,
#  'well': 15522,
#  'exercise': 5008,
#  'key': 7607,
#  'therapist': 14382,
#  'bonus': 1582,
#  'website': 15483,
#  'pt': 11311,
#  'total': 14591,
#  'take': 14021,
#  'us': 15037,
#  'weeks': 15506,
#  'care': 1952,
#  'vaulted': 15187,
#  'recreational': 11668,
#  'please': 10536,
#  'depending': 3655,
#  'licensing': 7969,
#  'cycling': 3344,
#  'dynamic': 4259,
#  'workout': 15724,
#  'information': 6977,
#  'situated': 13010,
#  'also': 548,
#  'personal': 10307,
#  'year': 15845,
#  'start': 13491,
#  'minutes': 8789,
#  'paid': 10036,
#  'encouraged': 4530,
#  'offers': 9595,
#  'performanceprofits': 10273,
#  'interest': 7209,
#  'keep': 7590,
#  'benefits': 1419,
#  'wwwandrewptcom': 15807,
#  'enthusiast': 4663,
#  'beach': 1361,
#  'vacation': 15134,
#  'manual': 8356,
#  'edge': 4322,
#  'treatment': 14718,
#  'continued': 2957,
#  'warm': 15415,
#  'johnandrewptgmailcom': 7511,
#  'happy': 6250,
#  'may': 8495,
#  'latest': 7776,
#  'spend': 13334,
#  'program': 11104,
#  'looking': 8158,
#  'square': 13408,
#  'competitive': 2665,
#  'feet': 5370,
#  'private': 10915,
#  'every': 4917,
#  'time': 14471,
#  'room': 12338,
#  'positive': 10654,
#  'contact': 2918,
#  'employee': 4468,
#  'education': 4338,
#  'wks': 15672,
#  'salary': 12417,
#  'environment': 4684,
#  'email': 4427,
#  'area': 886,
#  'welcome': 15515,
#  'including': 6858,
#  'experience': 5055,
#  'health': 6308,
#  'ingredients': 7018,
#  'hiking': 6446,
#  'daily': 3352,
#  'quick': 11461,
#  'ceiling': 2059,
#  'modalities': 8851,
#  'major': 8264,
#  'clinicians': 2358,
#  'dpt': 4178,
#  'yearly': 15849,
#  'equipped': 4769,
#  'approach': 817,
#  'better': 1452,
#  'skills': 13035,
#  'graduates': 6092,
#  'outpatient': 9952,
#  'necessary': 9146,
#  'holidays': 6493,
#  'case': 2003,
#  'medical': 8549,
#  'continuing': 2959,
#  'load': 8093,
#  'womens': 15677,
#  'enjoyable': 4628,
#  'note': 9441,
#  'therapy': 14387,
#  'mcminnville': 8512,
#  'one': 9663,
#  'helps': 6365,
#  'clinical': 2354,
#  'andrew': 644,
#  'active': 202,
#  'rehabilitation': 11775,
#  'via': 15256,
#  'equipment': 4764,
#  'believe': 1399,
#  'makes': 8271,
#  'mountains': 8970,
#  'growth': 6162,
#  'life': 7976,
#  'learning': 7856,
#  'profit': 11094,
#  'mentorship': 8622,
#  'day': 3419,
#  'matching': 8447,
#  'caring': 1983,
#  'within': 15663,
#  'even': 4900,
#  'new': 9276,
#  'visit': 15310,
#  'successour': 13770,
#  'receive': 11612,
#  'stay': 13538,
#  'additional': 245,
#  'offholidays': 9598,
#  'phone': 10370,
#  'years': 15851,
#  'appearance': 755,
#  'background': 1278,
#  'manage': 8284,
#  'training': 14649,
#  'mishandled': 8794,
#  'ownership': 10005,
#  'drive': 4202,
#  'toyota': 14606,
#  'attention': 1104,
#  'customer': 3296,
#  'come': 2532,
#  'fantastic': 5285,
#  'organized': 9851,
#  'lunchesresponsibilities': 8204,
#  'ability': 26,
#  'consistently': 2867,
#  'wellgroomed': 15532,
#  'maus': 8484,
#  'management': 8287,
#  'willing': 15629,
#  'david': 3418,
#  'sales': 12420,
#  'whether': 15584,
#  'critical': 3204,
#  'individuals': 6917,
#  'courteous': 3115,
#  'make': 8266,
#  'strive': 13658,
#  'demonstrated': 3616,
#  'oversee': 9981,
#  'billingual': 1484,
#  'screen': 12585,
#  'check': 2192,
#  'preemployment': 10775,
#  'assignments': 1033,
#  'ensure': 4640,
#  'friendly': 5754,
#  'reward': 12226,
#  'employees': 4474,
#  'award': 1232,
#  'winning': 15647,
#  'clean': 2300,
#  'carrying': 1998,
#  'insurance': 7147,
#  'promise': 11197,
#  'distribute': 4051,
#  'leave': 7869,
#  'plus': 10546,
#  'person': 10306,
#  'inventory': 7305,
#  'details': 3768,
#  'personality': 10309,
#  'expect': 5039,
#  'sold': 13196,
#  'dealership': 3462,
#  'allow': 530,
#  'communication': 2575,
#  'drug': 4215,
#  'delivering': 3589,
#  'ready': 11568,
#  'saturday': 12465,
#  'submit': 13717,
#  'absolutely': 54,
#  'laneensure': 7729,
#  'service': 12783,
#  'community': 2592,
#  'owner': 10003,
#  'professional': 11073,
#  'spanish': 13288,
#  'impression': 6801,
#  'concierge': 2773,
#  'effective': 4353,
#  'record': 11650,
#  'efficientlyqualifications': 4369,
#  'provide': 11276,
#  'flow': 5550,
#  'customers': 3303,
#  'vision': 15303,
#  'assure': 1065,
#  'technicians': 14202,
#  'prompt': 11209,
#  'get': 5970,
#  'driving': 4209,
#  'value': 15152,
#  'others': 9904,
#  'support': 13852,
#  'hard': 6254,
#  'inquiries': 7075,
#  'teamwork': 14186,
#  'forecast': 5608,
#  'complies': 2709,
#  'regard': 11729,
#  'supervision': 13835,
#  'excellent': 4964,
#  'building': 1775,
#  'jobs': 7503,
#  'water': 15432,
#  'overall': 9968,
#  'employer': 4483,
#  'software': 13177,
#  'required': 11949,
#  'members': 8587,
#  'gender': 5927,
#  'control': 2983,
#  'without': 15664,
#  'equal': 4755,
#  'continue': 2956,
#  'science': 12533,
#  'develop': 3786,
#  'use': 15058,
#  'client': 2322,
#  'costs': 3080,
#  'levels': 7918,
#  'ensuring': 4642,
#  'member': 8584,
#  'experienced': 5071,
#  'must': 9060,
#  'scheduling': 12519,
#  'general': 5928,
#  'opportunities': 9761,
#  'perform': 10266,
#  'negotiate': 9203,
#  'ongoing': 9683,
#  'exposures': 5179,
#  'process': 10980,
#  'schedule': 12511,
#  'people': 10240,
#  'curriculum': 3292,
#  'progress': 11158,
#  'buyout': 1832,
#  'identifying': 6709,
#  'safety': 12411,
#  'conditions': 2789,
#  'documentation': 4102,
#  'cooperative': 3021,
#  'priority': 10911,
#  'coordination': 3028,
#  'direction': 3923,
#  'conflict': 2824,
#  'responsibilities': 12085,
#  'herein': 6372,
#  'operational': 9731,
#  'team': 14102,
#  'field': 5396,
#  'closeout': 2366,
#  'requirements': 11973,
#  'nature': 9125,
#  'terms': 14310,
#  'safe': 12406,
#  'verbal': 15214,
#  'exemplify': 5004,
#  'related': 11801,
#  'location': 8116,
#  'practices': 10729,
#  'internal': 7226,
#  'personnel': 10316,
#  'state': 13501,
#  'exceeding': 4953,
#  'intended': 7188,
#  'size': 13018,
#  'templates': 14284,
#  'departments': 3640,
#  'providing': 11284,
#  'good': 6053,
#  'budget': 1751,
#  'vietnam': 15273,
#  'programs': 11136,
#  'position': 10636,
#  'special': 13307,
#  'promote': 11202,
#  'cost': 3077,
#  'religion': 11844,
#  'list': 8054,
#  'plan': 10452,
#  'governing': 6065,
#  'describe': 3675,
#  'knowledge': 7655,
#  'construction': 2881,
#  'analyze': 625,
#  'disabled': 3952,
#  'era': 4778,
#  'policy': 10599,
#  'promotion': 11206,
#  'summary': 13798,
#  'evaluation': 4894,
#  'disability': 3946,
#  'million': 8746,
#  'working': 15714,
#  'track': 14615,
#  'llc': 8087,
#  'resolution': 12047,
#  'maintain': 8246,
#  'furthermore': 5841,
#  'sex': 12850,
#  'subcontracts': 13705,
#  'age': 394,
#  'relationships': 11809,
#  'absence': 48,
#  'motivating': 8955,
#  'local': 8104,
#  'statements': 13511,
#  'federal': 5351,
#  'origin': 9860,
#  'discretion': 3995,
#  'manager': 8309,
#  'expertise': 5157,
#  'written': 15798,
#  'subject': 13710,
#  'leaves': 7870,
#  'veteran': 15245,
#  'needs': 9182,
#  'completion': 2689,
#  'initial': 7024,
#  'classified': 2296,
#  'nondiscrimination': 9391,
#  'labor': 7695,
#  'placement': 10445,
#  'employment': 4494,
#  'priorities': 10904,
#  'significant': 12952,
#  'change': 2138,
#  'color': 2518,
#  'university': 14955,
#  'accordance': 115,
#  'duties': 4240,
#  'preferred': 10782,
#  'communicate': 2570,
#  'activities': 205,
#  'establish': 4812,
#  'capable': 1929,
#  'bachelor': 1265,
#  'utilize': 15119,
#  'laws': 7798,
#  'plw': 10569,
#  'project': 11165,
#  'possess': 10658,
#  'webber': 15472,
#  'projects': 11173,
#  'satisfaction': 12458,
#  'external': 5197,
#  'contract': 2964,
#  'less': 7897,
#  'subcontractor': 13703,
#  'complete': 2680,
#  'applicants': 769,
#  'termination': 14307,
#  'profits': 11101,
#  'clear': 2309,
#  'national': 9113,
#  'responsible': 12119,
#  'performed': 10280,
#  'limited': 8023,
#  'compensation': 2648,
#  'procedures': 10961,
#  'applies': 797,
#  'wastewater': 15428,
#  'number': 9480,
#  'material': 8455,
#  'superior': 13828,
#  'hiring': 6459,
#  'financial': 5447,
#  'provides': 11283,
#  'race': 11480,
#  'applicable': 766,
#  'outcome': 9924,
#  'travel': 14703,
#  'expected': 5047,
#  'status': 13532,
#  'operates': 9727,
#  'job': 7492,
#  'effectively': 4354,
#  'accredited': 145,
#  'managing': 8329,
#  'leadership': 7826,
#  'units': 14947,
#  'providers': 11281,
#  'eight': 4383,
#  'worth': 15775,
#  'malpractice': 8279,
#  'ambulatory': 578,
#  'dallasfort': 3360,
#  'strategic': 13613,
#  'join': 7515,
#  'implementing': 6791,
#  'areas': 896,
#  'achieving': 168,
#  'women’s': 15680,
#  'renamed': 11873,
#  'services': 12798,
#  'dallas': 3359,
#  'continuous': 2961,
#  'children’s': 2223,
#  'dfw': 3854,
#  'skilled': 13032,
#  'worklife': 15718,
#  'trusted': 14767,
#  'resources': 12064,
#  'infrastructure': 6999,
#  'base': 1319,
#  'nicu': 9316,
#  'practitioner': 10745,
#  'contracts': 2969,
#  'nursery': 9487,
#  'oklahoma': 9638,
#  'alliance': 522,
#  'neonatologist': 9220,
#  'excellence': 4957,
#  'best': 1438,
#  'depth': 3672,
#  'referral': 11708,
#  'collegial': 2513,
#  'evidence': 4925,
#  'physicians': 10393,
#  'busy': 1821,
#  'healthcare': 6309,
#  'seeking': 12658,
#  'combining': 2530,
#  'consists': 2869,
#  'mission': 8798,
#  'nicus': 9317,
#  'prides': 10881,
#  'recently': 11619,
#  'patient': 10149,
#  'level': 7910,
#  'breadth': 1661,
#  'region’s': 11742,
#  'outcomes': 9927,
#  'practitioners': 10746,
#  'intensive': 7192,
#  'city': 2277,
#  'practice': 10724,
#  'balance': 1291,
#  'dedicated': 3522,
#  'robust': 12296,
#  'includes': 6853,
#  'communities': 2587,
#  'facilities': 5227,
#  'collaborative': 2488,
#  'stateoftheart': 13516,
#  'covering': 3128,
#  'neonatal': 9217,
#  'caremedical': 1970,
#  'partner': 10098,
#  'serveenvision': 12769,
#  'tail': 14016,
#  'several': 12848,
#  'nurse': 9485,
#  'emergency': 4451,
#  'comprehensive': 2723,
#  'iii': 6729,
#  'largest': 7763,
#  'would': 15777,
#  'hospitals': 6546,
#  'metroplex': 8674,
#  'part': 10083,
#  'technology': 14240,
#  'practicing': 10742,
#  'share': 12866,
#  'sites': 13002,
#  'exceptional': 4972,
#  'mfm': 8683,
#  'medicinewith': 8559,
#  'systems': 13956,
#  'envision': 4741,
#  'physician': 10389,
#  'established': 4813,
#  'matters': 8474,
#  'offcampus': 9583,
#  'deliver': 3578,
#  'highquality': 6430,
#  'statedesignated': 13505,
#  'mckinney’s': 8507,
#  'ages': 406,
#  'unit': 14940,
#  'gestational': 5969,
#  'focused': 5567,
#  'infants': 6950,
#  'serves': 12782,
#  'treat': 14715,
#  'ill': 6734,
#  'critically': 3206,
#  'premature': 10819,
#  'specialized': 13313,
#  'require': 11947,
#  'lewisville’s': 7940,
#  'offer': 9587,
#  'family': 5269,
#  'carethe': 1977,
#  'model': 8854,
#  'francis': 5717,
#  'nation': 9112,
#  'updates': 15003,
#  'become': 1375,
#  'pathophysiology': 10143,
#  'facility': 5230,
#  'assistant': 1040,
#  'penrosest': 10238,
#  'essential': 4806,
#  'coloradothe': 2520,
#  'possesses': 10659,
#  'undergone': 14900,
#  'beds': 1380,
#  'autonomous': 1203,
#  'first': 5483,
#  'nnp': 9353,
#  'set': 12840,
#  'making': 8272,
#  'couplet': 3109,
#  'penrose': 10237,
#  'bonusenvision': 1584,
#  'encourages': 4531,
#  'roomspenrosest': 12342,
#  'kind': 7632,
#  'amiable': 590,
#  'recent': 11618,
#  'fullservice': 5794,
#  'neonatologists': 9221,
#  'equitable': 4770,
#  'package': 10021,
#  'centura': 2087,
#  'hospitalswe': 6548,
#  'fourth': 5682,
#  'initiative': 7029,
#  'acute': 223,
#  'ethics': 4873,
#  'decision': 3494,
#  'america’s': 588,
#  'springs': 13386,
#  'named': 9095,
#  'hospital': 6542,
#  'resolve': 12056,
#  'exhibit': 5019,
#  'familycentered': 5271,
#  'parents': 10070,
#  'selfconfidence': 12682,
#  'independent': 6890,
#  'fair': 5254,
#  'babyfriendly': 1263,
#  'st': 13423,
#  'skill': 13031,
#  'row': 12373,
#  'ideal': 6694,
#  'proactive': 10922,
#  'leader': 7820,
#  'aims': 449,
#  'colorado': 2519,
#  'expansion': 5038,
#  'candidate': 1898,
#  'verify': 15225,
#  'co': 2427,
#  'strong': 13663,
#  'understanding': 14911,
#  'date': 3415,
#  'center': 2068,
#  'certified': 2104,
#  'able': 32,
#  'eligible': 4414,
#  'throughout': 14444,
#  'childrens': 2222,
#  'acuity': 217,
#  'admission': 296,
#  'group': 6145,
#  'guaranteed': 6177,
#  'resuscitation': 12158,
#  'tx': 14828,
#  'electrolytes': 4397,
#  'certificationclinical': 2099,
#  'cover': 3120,
#  'requirement': 11971,
#  'va': 15130,
#  'coordinator': 3030,
#  'fulfilled': 5783,
#  'credentialing': 3182,
#  'license': 7956,
#  'individualized': 6915,
#  'adapt': 231,
#  'lead': 7818,
#  'cme': 2415,
#  'technical': 14196,
#  'committed': 2561,
#  'include': 6845,
#  'licenses': 7965,
#  'setting': 12842,
#  'al': 474,
#  'obtaining': 9558,
#  'existing': 5026,
#  'cardiovascular': 1948,
#  'performance': 10267,
#  'nnps': 9357,
#  'line': 8031,
#  'evps': 4935,
#  'respventilator': 12124,
#  'match': 8443,
#  'current': 3287,
#  'la': 7691,
#  'proficient': 11088,
#  'stlt': 13570,
#  'fluids': 5560,
#  'intubation': 7293,
#  'assist': 1036,
#  'neonates': 9219,
#  'years’': 15859,
#  'regionalize': 11737,
#  'close': 2362,
#  'dues': 4231,
#  'triage': 14729,
#  'tube': 14789,
#  'focus': 5566,
#  'offering': 9590,
#  'varying': 15181,
#  'developing': 3797,
#  'catheterization': 2030,
#  'board': 1567,
#  'volume': 15348,
#  'credentialinglicensing': 3183,
#  'goal': 6020,
#  'autonomously': 1204,
#  'infection': 6951,
#  'flexible': 5525,
#  'second': 12633,
#  'ie': 6719,
#  'allowancecell': 532,
#  'home': 6502,
#  'nationwidethe': 9120,
#  'nm': 9348,
#  'greatest': 6118,
#  'nrp': 9467,
#  'embassador': 4431,
#  'states': 13517,
#  'fl': 5514,
#  'country': 3098,
#  'stabilization': 13426,
#  'reimbursement': 11782,
#  'az': 1248,
#  'licensed': 7959,
#  'chest': 2210,
#  'nnpbc': 9354,
#  'licensure': 7971,
#  'umbilical': 14885,
#  'try': 14776,
#  'multiple': 9033,
#  'annual': 687,
#  'hour': 6561,
#  'hope': 6528,
#  'adc': 239,
#  'arlington': 933,
#  'array': 946,
#  'considering': 2862,
#  'settings': 12844,
#  'gulf': 6200,
#  'colleague': 2493,
#  'development': 3799,
#  'mentoring': 8619,
#  'bed': 1378,
#  'advancement': 329,
#  'deliveriesprocedurestransport': 3588,
#  'studentsenvision': 13684,
#  'rns': 12282,
#  'census': 2066,
#  '“a”': 15959,
#  'days': 3428,
#  'nationallyrecognized': 9117,
#  'nights': 9322,
#  'since': 12987,
#  'america': 582,
#  'options': 9800,
#  'industry': 6925,
#  'highlights': 6409,
#  'contractor': 2967,
#  'corporation': 3053,
#  '•': 15992,
#  'backed': 1272,
#  'optimal': 9778,
#  'attendance': 1099,
#  'step': 13548,
#  'hca': 6294,
#  'organization': 9833,
#  'expanding': 5036,
#  'meticulous': 8666,
#  'benefit': 1417,
#  'delivers': 3592,
#  'vast': 15183,
#  'coasttocoast': 2435,
#  'minimum': 8773,
#  'specialty': 13316,
#  'physicianled': 10391,
#  'shift': 12887,
#  'rated': 11521,
#  'unmatched': 14978,
#  'wide': 15610,
#  'teaching': 14099,
#  'supported': 13857,
#  'regional': 11736,
#  'opportunity': 9769,
#  'career': 1957,
#  'staffing': 13440,
#  'neos': 9223,
#  'affiliated': 377,
#  'staff': 13438,
#  'variety': 15178,
#  'potentially': 10700,
#  'ratios': 11529,
#  'acutecare': 224,
#  'innovation': 7056,
#  'assured': 1066,
#  'pediatric': 10217,
#  'monsat': 8916,
#  'integration': 7162,
#  'enjoy': 4627,
#  'average': 1222,
#  'gcrmc': 5915,
#  'extensive': 5195,
#  'division': 4078,
#  'sun': 13811,
#  'night': 9320,
#  'panama': 10047,
#  'coast': 2433,
#  'rnrt': 12280,
#  'liability': 7946,
#  'rest': 12125,
#  'vary': 15180,
#  'industryleader': 6932,
#  'policies': 10595,
#  'homebuilder': 6504,
#  'subsidiaries': 13733,
#  'branch': 1642,
#  'marketingbusiness': 8397,
#  'markets': 8404,
#  'pipeline': 10422,
#  'developmentsales': 3825,
#  'bachelors': 1266,
#  'moveup': 8975,
#  'engaged': 4566,
#  'functions': 5812,
#  'results': 12142,
#  'productionstaff': 11040,
#  'offices': 9607,
#  'inc': 6827,
#  'builder': 1769,
#  'strategy': 13624,
#  'outside': 9957,
#  'potential': 10696,
#  'fast': 5298,
#  'andor': 640,
#  'included': 6848,
#  'system': 13943,
#  'college': 2507,
#  'borrower': 1609,
#  'principally': 10890,
#  'review': 12197,
#  'like': 8014,
#  'earning': 4285,
#  'qualifications': 11404,
#  'address': 251,
#  'americas': 586,
#  'onsite': 9696,
#  'facebook': 5218,
#  'familiar': 5264,
#  'captive': 1937,
#  'meeting': 8572,
#  'weekend': 15494,
#  'basis': 1332,
#  'estate': 4818,
#  'clients': 2327,
#  'followup': 5587,
#  'informationdr': 6982,
#  'infrequently': 7009,
#  'originator': 9869,
#  'discrepancies': 3992,
#  'build': 1768,
#  'high': 6390,
#  'enthusiastic': 4664,
#  'b': 1256,
#  'success': 13761,
#  'traded': 14628,
#  'currently': 3290,
#  'attitudes': 1109,
#  'meet': 8570,
#  'business': 1797,
#  'manner': 8340,
#  'mortgages': 8944,
#  'fortune': 5655,
#  'financing': 5452,
#  'clearly': 2313,
#  'adequate': 259,
#  'postclosingfunding': 10676,
#  'realtors': 11586,
#  'fouryear': 5683,
#  'marketing': 8396,
#  'funding': 5828,
#  'combination': 2526,
#  'meetings': 8573,
#  'dr': 4179,
#  'floridaorange': 5541,
#  'noncaptive': 9379,
#  'publicly': 11323,
#  'york': 15874,
#  'content': 2936,
#  'homes': 6514,
#  'leads': 7840,
#  'relationship': 11807,
#  'buyers': 1825,
#  'officer': 9603,
#  'obtain': 9556,
#  'qc': 11392,
#  'conversation': 2995,
#  'application': 771,
#  'represent': 11923,
#  'origination': 9867,
#  'detailed': 3760,
#  'attend': 1098,
#  'purpose': 11351,
#  'equivalent': 4772,
#  'primary': 10883,
#  'educate': 4334,
#  'sale': 12418,
#  'right': 12254,
#  'description': 3679,
#  'homebuyers': 6505,
#  'twitter': 14822,
#  'title': 14514,
#  'underwriting': 14916,
#  'purchase': 11344,
#  'input': 7069,
#  'presentations': 10845,
#  'mortgage’s': 8945,
#  'problems': 10934,
#  'annually': 688,
#  'loans': 8099,
#  'originations': 9868,
#  'entrylevel': 4681,
#  'materials': 8456,
#  'jun': 7553,
#  'loan': 8098,
#  'products': 11050,
#  'future': 5844,
#  'cards': 1951,
#  'representatives': 11928,
#  'provided': 11277,
#  'open': 9710,
#  'posting': 10686,
#  'stock': 13572,
#  'wwwdrhortoncom': 15811,
#  'quarterly': 11443,
#  'assigned': 1023,
#  'dhi': 3856,
#  'designed': 3719,
#  'players': 10519,
#  'comply': 2712,
#  'follow': 5575,
#  'sources': 13265,
#  'prospective': 11248,
#  'founded': 5674,
#  'visitorlead': 15312,
#  'prepare': 10827,
#  'horton': 6539,
#  'log': 8129,
#  'real': 11571,
#  'automated': 1185,
#  'resolving': 12059,
#  'exchange': 4978,
#  'degree': 3554,
#  'two': 14823,
#  'signatures': 12948,
#  'opening': 9714,
#  'routinely': 12367,
#  'newest': 9281,
#  'train': 14641,
#  'grand': 6100,
#  'file': 5423,
#  'accuracy': 151,
#  'statecome': 13502,
#  'mortgage': 8943,
#  'industryrelated': 6937,
#  'floridaorlando': 5542,
#  'tennesseenolensville': 14294,
#  'school': 12529,
#  'name': 9094,
#  'appropriate': 822,
#  'occasionally': 9563,
#  'immediately': 6753,
#  'parties': 10095,
#  'mlo’s': 8832,
#  'unlicensed': 14966,
#  'consumer': 2901,
#  'administrative': 290,
#  'side': 12932,
#  'order': 9821,
#  'outstanding': 9961,
#  'loa': 8092,
#  'rates': 11523,
#  'communicating': 2573,
#  'appraisal': 808,
#  'handling': 6232,
#  'sure': 13869,
#  'six': 13015,
#  'requests': 11943,
#  'assistants': 1045,
#  'strictly': 13656,
#  'processors': 11007,
#  'applications': 777,
#  'select': 12670,
#  '–': 15938,
#  'ged': 5922,
#  'processing': 11003,
#  'call': 1869,
#  'transaction': 14663,
#  'etc': 4830,
#  'producing': 11024,
#  'diploma': 3916,
#  'product': 11026,
#  'electronic': 4399,
#  'approval': 827,
#  'los': 8163,
#  'negotiating': 9205,
#  'made': 8228,
#  'ast': 1069,
#  'update': 15001,
#  'moving': 8978,
#  'laurel': 7791,
#  'verifications': 15222,
#  'months': 8924,
#  'jerseymount': 7480,
#  'calls': 1874,
#  'appointments': 804,
#  '“set': 15979,
#  'prohibited': 11163,
#  'preparing': 10831,
#  'returning': 12182,
#  'weeklydaily': 15501,
#  'up”': 15030,
#  'referred': 11710,
#  'originating': 9866,
#  'basic': 1330,
#  'documents': 4116,
#  'assignedimportant': 1026,
#  'individual': 6913,
#  ...}

# %%
desc4 = df['Description'][3]

# %%
print(desc4)
# Out:
# <p>Envision Physician Services is seeking a Neonatal Nurse Practitioner to join our busy practice covering 7 Medical City facilities in the DFW area. The practice prides itself in delivering quality excellence, continued education and work-life balance. The Neonatal Intensive Care Units are all level 3 facilities and have a continuous MFM referral base. Our collaborative team consists of skilled Neonatal Nurse Practitioners and Neonatologist covering several Medical City NICUs in the Dallas Metroplex. You would join a collegial team of clinicians who are dedicated to achieving the best patient outcomes by implementing and practicing evidence based medicine.</p><p>With over 30 years of high-quality Women&rsquo;s &amp; Children&rsquo;s services and more than 100 service contracts, Envision Physician Services is a trusted strategic partner for established hospitals and health systems. Combining a national infrastructure with local support, our breadth and depth of clinical and operational resources allow our physicians to spend more time on what matters: delivering high-quality care.</p><br /><p>Medical City Alliance is a level III NICU with eight private rooms, equipped with state-of-the-art, intensive care nursery technology. The Medical City facilities are part of one of the region&rsquo;s largest, most comprehensive health care providers, recently renamed, Medical City Healthcare. Spanning the Dallas-Fort Worth and Oklahoma City areas, Medical City Healthcare includes 13 hospitals, 7 off-campus emergency rooms, more than 50 ambulatory sites, more than 7,000 active physicians and 15,000 employees. We share in their mission to deliver exceptional healthcare to the communities we serve.</p><br />Envision offers competitive compensation, a robust benefits effective on day one, and malpractice insurance with tail coverage.

# %%
bow4 = bow_transformer.transform([desc4])

# %%
print('shape: ',bow4.shape)
print(bow4)
# Out:
# shape:  (1, 15995)
#   (0, 168)	1
#   (0, 202)	1
#   (0, 522)	1
#   (0, 530)	1
#   (0, 578)	1
#   (0, 886)	1
#   (0, 896)	1
#   (0, 1291)	1
#   (0, 1319)	1
#   (0, 1322)	1
#   (0, 1419)	1
#   (0, 1438)	1
#   (0, 1661)	1
#   (0, 1821)	1
#   (0, 1952)	1
#   (0, 1970)	1
#   (0, 2223)	1
#   (0, 2277)	1
#   (0, 2354)	1
#   (0, 2358)	1
#   (0, 2488)	1
#   (0, 2513)	1
#   (0, 2530)	1
#   (0, 2587)	1
#   (0, 2648)	1
#   :	:
#   (0, 12658)	1
#   (0, 12769)	1
#   (0, 12783)	1
#   (0, 12798)	1
#   (0, 12848)	1
#   (0, 12866)	1
#   (0, 13002)	1
#   (0, 13032)	1
#   (0, 13289)	1
#   (0, 13334)	1
#   (0, 13516)	1
#   (0, 13613)	1
#   (0, 13852)	1
#   (0, 13956)	1
#   (0, 14016)	1
#   (0, 14102)	1
#   (0, 14240)	1
#   (0, 14471)	1
#   (0, 14767)	1
#   (0, 14947)	1
#   (0, 15680)	1
#   (0, 15718)	1
#   (0, 15775)	1
#   (0, 15777)	1
#   (0, 15851)	1

# %%
bow_transformer.get_feature_names()[168]
# Out:
# 'achieving'

# %%
desc_bow = bow_transformer.transform(df['Description'])

# %%
print('Shape of Sparse Matrix: ', desc_bow.shape)
# Out:
# Shape of Sparse Matrix:  (1097, 15995)

# %%
desc_bow.nnz
# Out:
# 196891

# %% [markdown]
# ## TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfTransformer

# %%
tfidf_transformer = TfidfTransformer().fit(desc_bow)

# %%
tfidf4 = tfidf_transformer.transform(bow4)

# %%
print(tfidf4)
# Out:
#   (0, 15851)	0.03542906448237975
#   (0, 15777)	0.07522867069978371
#   (0, 15775)	0.1024144446705049
#   (0, 15718)	0.0927302015994328
#   (0, 15680)	0.09893011811152702
#   (0, 14947)	0.06773789515730765
#   (0, 14767)	0.09665249650184064
#   (0, 14471)	0.03923183197466988
#   (0, 14240)	0.05180564712482586
#   (0, 14102)	0.0289753013158673
#   (0, 14016)	0.10059960696456373
#   (0, 13956)	0.047711743635683146
#   (0, 13852)	0.04452607179711902
#   (0, 13613)	0.06922834878244388
#   (0, 13516)	0.09738441286206931
#   (0, 13334)	0.07326416312362723
#   (0, 13289)	0.11184171353433582
#   (0, 13032)	0.0629403329799821
#   (0, 13002)	0.09974816319421731
#   (0, 12866)	0.06536130550435747
#   (0, 12848)	0.07768532753737055
#   (0, 12798)	0.036933671243693525
#   (0, 12783)	0.04434956177909421
#   (0, 12769)	0.12629901420660233
#   (0, 12658)	0.055358621499973094
#   :	:
#   (0, 2648)	0.06668603483890592
#   (0, 2587)	0.05319088477261714
#   (0, 2530)	0.10148729310021418
#   (0, 2513)	0.11687174534277141
#   (0, 2488)	0.06279796057745507
#   (0, 2358)	0.10148729310021418
#   (0, 2354)	0.06922834878244388
#   (0, 2277)	0.0852908625219508
#   (0, 2223)	0.09459928504722387
#   (0, 1970)	0.13331697580138688
#   (0, 1952)	0.045805325207486015
#   (0, 1821)	0.11184171353433582
#   (0, 1661)	0.10059960696456373
#   (0, 1438)	0.04913601531908209
#   (0, 1419)	0.04423271286852868
#   (0, 1322)	0.05777806606009851
#   (0, 1319)	0.08943004821048864
#   (0, 1291)	0.07234720333266682
#   (0, 896)	0.06536130550435747
#   (0, 886)	0.061292834087848413
#   (0, 578)	0.11338741878379353
#   (0, 530)	0.09101492244044257
#   (0, 522)	0.12951420830909674
#   (0, 202)	0.08368564945471038
#   (0, 168)	0.1024144446705049

# %%
tfidf_transformer.idf_[bow_transformer.vocabulary_['salary']]
# Out:
# 4.012261575505201

# %%
desc_tfidf = tfidf_transformer.transform(desc_bow)

# %% [markdown]
# ## Naive bayes

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
nb_model = MultinomialNB().fit(desc_tfidf, df['JobTitle'])

# %%
nb_model.predict(tfidf4)[0]
# Out:
# 'Neonatal Nurse'

# %%
df.iloc[[3],:]
# Out:
#       JobId  JobTitleId        JobTitle  \
# 3  88112060      402654  Neonatal Nurse
#
#                                                                                                                                              Description  \
# 3  <p>Envision Physician Services is seeking a Neonatal Nurse Practitioner to join our busy practice covering 7 Medical City facilities in the DFW ar...
#
#                                                                                                                                                     Desc  \
# 3  [units, providers, coverage, eight, based, worth, malpractice, years, ambulatory, dallasfort, strategic, join, rooms, implementing, areas, quality...
#
#    DescLength  DescriptionLength
# 3         132               1850

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df['Description'], df['JobTitle'], test_size=0.3, random_state=42)

# %%
from sklearn.pipeline import Pipeline

# %%
pipline = Pipeline([
    ('bow', CountVectorizer(analyzer=text_process)),
    ('tfidf', TfidfTransformer()),
    ('classifier', MultinomialNB())
])

# %%
pipline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('bow',
#                  CountVectorizer(analyzer=<function text_process at 0x0000029345BAD040>)),
#                 ('tfidf', TfidfTransformer()),
#                 ('classifier', MultinomialNB())])

# %%
predictions = pipline.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, predictions))
# Out:
#                                          precision    recall  f1-score   support
#
#           Assistant Director of Nursing       0.00      0.00      0.00         2
#              Automotive Service Manager       0.00      0.00      0.00        10
#               Business Planning Analyst       0.00      0.00      0.00         3
#                      Content Strategist       1.00      0.14      0.25         7
#                   Data Science Director       0.00      0.00      0.00         6
#                    Enterprise Developer       0.00      0.00      0.00         1
#                        Facility Planner       0.00      0.00      0.00         1
#                         Freight Manager       0.00      0.00      0.00         2
#                 Growth Strategy Manager       0.00      0.00      0.00         8
#               Human Resources Assistant       0.00      0.00      0.00        11
#           Hyperbaric Medicine Physician       0.00      0.00      0.00         1
#                       Infertility Nurse       0.00      0.00      0.00         1
#                 Installation Specialist       0.00      0.00      0.00         3
#                  Internship Coordinator       0.00      0.00      0.00         1
#                Land Acquisition Manager       0.00      0.00      0.00         1
#                  Law - Faculty Position       0.00      0.00      0.00         1
#                            Loan Officer       0.93      0.90      0.92        30
#                     Maintenance Planner       0.00      0.00      0.00         7
# Manufacturing and Engineering Recruiter       0.00      0.00      0.00         2
#     Medical Laboratory Technician (MLT)       0.00      0.00      0.00        14
#                          Neonatal Nurse       1.00      0.14      0.25         7
#                       Neuropsychologist       0.00      0.00      0.00         5
#        Online Marketing Program Manager       0.00      0.00      0.00         1
#              Pediatric Anesthesiologist       0.00      0.00      0.00         7
#      Physical Therapist Assistant (PTA)       0.95      0.92      0.93        60
#                         Press Assistant       0.00      0.00      0.00         1
#                       Process Associate       0.00      0.00      0.00         8
#                 Product Design Engineer       0.00      0.00      0.00         1
#                         Records Manager       0.00      0.00      0.00         1
#           Regulatory Compliance Auditor       0.00      0.00      0.00         2
#               Small Animal Veterinarian       0.00      0.00      0.00         7
#                       Software Engineer       0.40      1.00      0.57        96
#                      Standards Engineer       0.00      0.00      0.00         2
#              Sterile Processing Manager       0.00      0.00      0.00         1
#               Supervisor Security Guard       0.00      0.00      0.00         1
#                             Tax Analyst       0.00      0.00      0.00         5
#              Wastewater Project Manager       0.00      0.00      0.00         1
#                              Wholesaler       1.00      0.17      0.29        12
#
#                                accuracy                           0.55       330
#                               macro avg       0.14      0.09      0.08       330
#                            weighted avg       0.45      0.55      0.44       330
# C:\Users\yhadad\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
pipline = Pipeline([
    ('bow', CountVectorizer(analyzer=text_process)),
    ('tfidf', TfidfTransformer()),
    ('classifier', RandomForestClassifier())
])

# %%
pipline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('bow',
#                  CountVectorizer(analyzer=<function text_process at 0x0000029345BAD040>)),
#                 ('tfidf', TfidfTransformer()),
#                 ('classifier', RandomForestClassifier())])

# %%
predictions = pipline.predict(X_test)

# %%
print(classification_report(y_test, predictions))
# Out:
#                                          precision    recall  f1-score   support
#
#           Assistant Director of Nursing       1.00      1.00      1.00         2
#              Automotive Service Manager       0.82      0.90      0.86        10
#               Business Planning Analyst       0.00      0.00      0.00         3
#                      Content Strategist       1.00      0.86      0.92         7
#                   Data Science Director       1.00      0.33      0.50         6
#                    Enterprise Developer       0.00      0.00      0.00         1
#                        Facility Planner       0.00      0.00      0.00         1
#                         Freight Manager       1.00      1.00      1.00         2
#                 Growth Strategy Manager       1.00      0.75      0.86         8
#               Human Resources Assistant       1.00      0.64      0.78        11
#           Hyperbaric Medicine Physician       0.00      0.00      0.00         1
#                       Infertility Nurse       0.00      0.00      0.00         1
#                 Installation Specialist       1.00      0.33      0.50         3
#                  Internship Coordinator       0.00      0.00      0.00         1
#                Land Acquisition Manager       1.00      1.00      1.00         1
#                  Law - Faculty Position       0.00      0.00      0.00         1
#                            Loan Officer       0.93      0.90      0.92        30
#                     Maintenance Planner       1.00      0.86      0.92         7
# Manufacturing and Engineering Recruiter       1.00      1.00      1.00         2
#     Medical Laboratory Technician (MLT)       1.00      0.29      0.44        14
#                          Neonatal Nurse       1.00      1.00      1.00         7
#                       Neuropsychologist       0.00      0.00      0.00         5
#        Online Marketing Program Manager       0.00      0.00      0.00         1
#              Pediatric Anesthesiologist       0.86      0.86      0.86         7
#      Physical Therapist Assistant (PTA)       0.95      1.00      0.98        60
#                         Press Assistant       0.00      0.00      0.00         1
#                       Process Associate       1.00      0.88      0.93         8
#                 Product Design Engineer       0.00      0.00      0.00         1
#                         Records Manager       0.00      0.00      0.00         1
#           Regulatory Compliance Auditor       0.00      0.00      0.00         2
#               Small Animal Veterinarian       1.00      0.14      0.25         7
#                       Software Engineer       0.63      1.00      0.77        96
#                      Standards Engineer       1.00      0.50      0.67         2
#              Sterile Processing Manager       0.50      1.00      0.67         1
#               Supervisor Security Guard       0.00      0.00      0.00         1
#                             Tax Analyst       0.00      0.00      0.00         5
#              Wastewater Project Manager       1.00      1.00      1.00         1
#                              Wholesaler       1.00      0.83      0.91        12
#
#                                accuracy                           0.80       330
#                               macro avg       0.57      0.48      0.49       330
#                            weighted avg       0.79      0.80      0.76       330
# C:\Users\yhadad\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
df.JobTitle.value_counts()
# Out:
# Software Engineer                          342
# Physical Therapist Assistant (PTA)         200
# Loan Officer                               116
# Content Strategist                          43
# Wholesaler                                  40
# Automotive Service Manager                  34
# Growth Strategy Manager                     30
# Neonatal Nurse                              26
# Human Resources Assistant                   24
# Medical Laboratory Technician (MLT)         24
# Pediatric Anesthesiologist                  21
# Data Science Director                       19
# Tax Analyst                                 16
# Maintenance Planner                         16
# Process Associate                           14
# Small Animal Veterinarian                   12
# Neuropsychologist                           11
# Assistant Director of Nursing               11
# Manufacturing and Engineering Recruiter      9
# Installation Specialist                      8
# Land Acquisition Manager                     7
# Press Assistant                              6
# Standards Engineer                           6
# Regulatory Compliance Auditor                6
# Infertility Nurse                            5
# Wastewater Project Manager                   5
# Freight Manager                              5
# Business Planning Analyst                    4
# Blender Operator                             4
# Broadcast Engineer                           3
# Sterile Processing Manager                   3
# CMM Operator                                 2
# Records Manager                              2
# Inventory Control  Manager                   2
# Facility Planner                             2
# Internship Coordinator                       2
# Information Services Manager                 2
# Hyperbaric Medicine Physician                2
# Online Marketing Program Manager             1
# Supervisor Security Guard                    1
# Airport Director                             1
# Welding Supervisor                           1
# eDiscovery Specialist                        1
# Law - Faculty Position                       1
# Preschool Director                           1
# Enterprise Developer                         1
# Marshal                                      1
# Product Design Engineer                      1
# Proctor                                      1
# Residence Life Director                      1
# Prosecutor                                   1
# Name: JobTitle, dtype: int64
